# %% [markdown]
# <a href="https://colab.research.google.com/github/askharshita/test/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
quiz_questions = [
    {
        "question": "What is the value of (sin 30° + cos 30°) - (sin 60° + cos 60°)?",
        "options": ["a) 0", "b) 1", "c) 2", "d) -1"],
        "answer": "a"
    },
    {
        "question": "If the difference between the circumference and radius of a circle is 37 cm, then using π = 22/7, the circumference (in cm) of the circle is:",
        "options": ["a) 154", "b) 44", "c) 14", "d) 7"],
        "answer": "b"
    },
    {
        "question": "The values of x and y in the given figure are:",
        "options": ["a) x=14, y=10", "b) x=21, y=42", "c) x=21, y=24", "d) x=10, y=14"],
        "answer": "c" # Note: This question ideally needs an image to be fully solvable. I will assume a common geometry problem setup for a class 10 level.
    },
    {
        "question": "A card is selected from a deck of 52 cards. The probability of its being a red face card is:",
        "options": ["a) 3/26", "b) 3/13", "c) 2/13", "d) 1/2"],
        "answer": "a"
    },
    {
        "question": "If one root of the quadratic equation 2x² + kx – 6 = 0 is 2, then the value of k is:",
        "options": ["a) 1", "b) -1", "c) 2", "d) -2"],
        "answer": "b"
    },
    {
        "question": "The distance between the points (a cos θ + b sin θ, 0) and (0, a sin θ – b cos θ) is:",
        "options": ["a) a² + b²", "b) √(a² + b²)", "c) a² - b²", "d) √(a² - b²)"],
        "answer": "b"
    },
    {
        "question": "The nth term of an AP is given by an = 3 + 4n. The common difference is:",
        "options": ["a) 3", "b) 4", "c) 7", "d) 1"],
        "answer": "b"
    },
    {
        "question": "In ΔABC, if DE || BC, AD = x, DB = x – 2, AE = x + 2 and EC = x – 1, then the value of x is:",
        "options": ["a) 2", "b) 3", "c) 4", "d) 5"],
        "answer": "c"
    },
    {
        "question": "The decimal expansion of the rational number 14587/1250 will terminate after:",
        "options": ["a) one decimal place", "b) two decimal places", "c) three decimal places", "d) four decimal places"],
        "answer": "d"
    },
    {
        "question": "If the sum of the zeroes of the quadratic polynomial 3x² – kx + 6 is 3, then the value of k is:",
        "options": ["a) 3", "b) -3", "c) 9", "d) -9"],
        "answer": "c"
    }
]

print("Quiz questions loaded successfully!")
# Out:
# Quiz questions loaded successfully!

# %%
def run_quiz(questions):
    score = 0
    print("\n--- Welcome to the Math Quiz for Class 10! ---\n")

    for i, q in enumerate(questions):
        print(f"Question {i + 1}: {q['question']}")
        for option in q['options']:
            print(option)

        while True:
            user_answer = input("Your answer (a, b, c, or d): ").strip().lower()
            if user_answer in ['a', 'b', 'c', 'd']:
                break
            else:
                print("Invalid input. Please enter 'a', 'b', 'c', or 'd'.")

        if user_answer == q['answer']:
            print("Correct!\n")
            score += 1
        else:
            print(f"Incorrect. The correct answer was {q['answer'].upper()}.\n")

    print("--- Quiz Finished! ---")
    print(f"You scored {score} out of {len(questions)}.")

# Run the quiz with the defined questions
run_quiz(quiz_questions)
# Out:
# --- Welcome to the Math Quiz for Class 10! ---
#
# Question 1: What is the value of (sin 30° + cos 30°) - (sin 60° + cos 60°)?
# a) 0
# b) 1
# c) 2
# d) -1
# Your answer (a, b, c, or d): c
# Incorrect. The correct answer was A.
#
# Question 2: If the difference between the circumference and radius of a circle is 37 cm, then using π = 22/7, the circumference (in cm) of the circle is:
# a) 154
# b) 44
# c) 14
# d) 7
# Your answer (a, b, c, or d): a
# Incorrect. The correct answer was B.
#
# Question 3: The values of x and y in the given figure are:
# a) x=14, y=10
# b) x=21, y=42
# c) x=21, y=24
# d) x=10, y=14
# Your answer (a, b, c, or d): d
# Incorrect. The correct answer was C.
#
# Question 4: A card is selected from a deck of 52 cards. The probability of its being a red face card is:
# a) 3/26
# b) 3/13
# c) 2/13
# d) 1/2
# Your answer (a, b, c, or d): e
# Invalid input. Please enter 'a', 'b', 'c', or 'd'.
# Your answer (a, b, c, or d): a
# Correct!
#
# ...
